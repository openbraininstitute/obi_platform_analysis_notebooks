# %%
from pathlib import Path
import importlib
import sys

notebook_dir = Path.cwd()
lib_dir = notebook_dir / 'lib'
if not lib_dir.is_dir():
    lib_dir = notebook_dir / 'Cellular' / 'validate_segmented_spines' / 'lib'
sys.path.insert(0, str(lib_dir))
importlib.invalidate_caches()

import validate_spines_core
validate_spines_core = importlib.reload(validate_spines_core)

mesh_path = '/scratch/data/skeletonizations/864691134886335738.glb'
morphology_path = '/scratch/data/skeletonizations/864691134886335738.h5'

validate_spines_core.validate_spines(
    morphology_path=morphology_path,
    mesh_path=mesh_path,
)
# Out:
# Validation Dataset
# ------------------
# Morphology: 864691134886335738.h5
# Mesh: 864691134886335738.glb
# Sections: 93 total | 63 with spines (67.7%)
# Total spines: 1,047
# Spines represented in spiny sections: 1,047
# Average spines per spiny section: 16.6
#
# Mesh Data
# ---------
# Indexed vertices: 1,086,592
# Displayed vertices: 162,989 (15% sample)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 18
#      14
#      15 mesh_path = '/scratch/data/skeletonizations/864691134886335738.glb'
#      16 morphology_path = '/scratch/data/skeletonizations/864691134886335738.h5'
#      17
# ---> 18 validate_spines_core.validate_spines(
#      19     morphology_path=morphology_path,
#      20     mesh_path=mesh_path,
#      21 )
#
# File /ssd1/projects/obi_platform_analysis_notebooks/Cellular/validate_segmented_spines/lib/validate_spines_core.py:2605, in validate_spines(morphology_path, mesh_path)
#    2603 btn_validity_invalid.on_click(on_validity_invalid)
#    2604 btn_screenshot.on_click(take_screenshot)
# -> 2605 btn_register_assessment.on_click(on_register_assessment)
#    2606 btn_generate_report.on_click(on_generate_report)
#    2607 plot.observe(on_screenshot_ready, names='screenshot')
#
# NameError: name 'on_register_assessment' is not defined
