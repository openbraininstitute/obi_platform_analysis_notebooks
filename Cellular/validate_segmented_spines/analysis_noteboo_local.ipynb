# %%
from pathlib import Path
import importlib
import sys

lib_dir = Path('lib')
sys.path.insert(0, str(lib_dir))
importlib.invalidate_caches()

import validate_spines_core
validate_spines_core = importlib.reload(validate_spines_core)

mesh_path = '/scratch/data/skeletonizations/864691134886335738.glb'
morphology_path = '/scratch/data/skeletonizations/864691134886335738.h5'

validate_spines_core.validate_spines(
    morphology_path=morphology_path,
    mesh_path=mesh_path,
)
# Out:
# Validation Dataset
# ------------------
# Morphology: 864691134886335738.h5
# Mesh: 864691134886335738.glb
# Sections: 87 total | 64 with spines (73.6%)
# Total spines: 1,057
# Spines represented in spiny sections: 1,057
# Average spines per spiny section: 16.5
#
# Mesh Data
# ---------
# Indexed vertices: 1,086,592
# Displayed vertices: 162,989 (15% sample)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 15
#      12 mesh_path = '/scratch/data/skeletonizations/864691134886335738.glb'
#      13 morphology_path = '/scratch/data/skeletonizations/864691134886335738.h5'
# ---> 15 validate_spines_core.validate_spines(
#      16     morphology_path=morphology_path,
#      17     mesh_path=mesh_path,
#      18 )
#
# File /ssd1/development/projects/obi_platform_analysis_notebooks/Cellular/validate_segmented_spines/lib/validate_spines_core.py:3318, in validate_spines(morphology_path, mesh_path)
#    3288     label_html = (
#    3289         f'<b>{label}</b> '
#    3290         f'<span title="{analysis_tooltips[label]}" '
#    3291         'style="cursor:help; color:#5f6368;">&#9432;</span>'
#    3292     )
#    3293     return widgets.HBox(
#    3294         [widgets.HTML(value=label_html, layout=analysis_label_layout), button_group],
#    3295         layout=widgets.Layout(
#    (...)   3304         ),
#    3305     )
#    3307 spine_analysis_controls = widgets.VBox([
#    3308     analysis_row(
#    3309         'False Positive',
#    3310         btn_false_positive_yes,
#    3311         btn_false_positive_no,
#    3312     ),
#    3313     analysis_row(
#    3314         'Incomplete Spine',
#    3315         btn_incomplete_spines_yes,
#    3316         btn_incomplete_spines_no,
#    3317     ),
# -> 3318     analysis_row(
#    3319         'Falsely Extended Spine',
#    3320         btn_false_positive_quality_yes,
#    3321         btn_false_positive_quality_no,
#    3322     ),
#    3323     analysis_row(
#    3324         'Merged Spine',
#    3325         btn_merged_spine_yes,
#    3326         btn_merged_spine_no,
#    3327     ),
#    3328     analysis_row(
#    3329         'Split Spine',
#    3330         btn_split_spine_yes,
#    3331         btn_split_spine_no,
#    3332     ),
#    3333     analysis_row(
#    3334         'Validity',
#    3335         btn_validity_valid,
#    3336         btn_validity_invalid,
#    3337     ),
#    3338 ], layout=widgets.Layout(width='100%'))
#    3340 # The current ipywidgets theme uses a 30 px default button height. Set every
#    3341 # button to 27 px (90% of the default) while preserving its existing width,
#    3342 # style, and other layout properties.
#    3343 button_height = '25px'
#
# File /ssd1/development/projects/obi_platform_analysis_notebooks/Cellular/validate_segmented_spines/lib/validate_spines_core.py:3290, in validate_spines.<locals>.analysis_row(label, yes_button, no_button)
#    3270     button.layout = widgets.Layout(
#    3271         width=analysis_button_width,
#    3272         min_width=analysis_button_width,
#    3273         max_width=analysis_button_width,
#    3274         padding='0 4px',
#    3275     )
#    3277 button_group = widgets.HBox(
#    3278     [yes_button, no_button],
#    3279     layout=widgets.Layout(
#    (...)   3286     ),
#    3287 )
#    3288 label_html = (
#    3289     f'<b>{label}</b> '
# -> 3290     f'<span title="{analysis_tooltips[label]}" '
#    3291     'style="cursor:help; color:#5f6368;">&#9432;</span>'
#    3292 )
#    3293 return widgets.HBox(
#    3294     [widgets.HTML(value=label_html, layout=analysis_label_layout), button_group],
#    3295     layout=widgets.Layout(
#    (...)   3304     ),
#    3305 )
#
# KeyError: 'Falsely Extended Spine'

# %%
import k3d 
print(k3d.__version__)
# Out:
# 2.18.1
