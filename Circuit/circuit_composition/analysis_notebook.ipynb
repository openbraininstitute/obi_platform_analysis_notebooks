# %% [markdown]
# # Circuit composition
#
# Copyright (c) 2025 Open Brain Institute
#
# Authors: Michael W. Reimann
#
# last modified: 05.2026
#
# ## Summary
# This notebook lists the neuronal composition of a (SONATA) circuit model as a Sankey plot.
# From the first dropdown menu select the [node set](https://sonata-extension.readthedocs.io/en/latest/sonata_nodeset.html) you want to display the composition of.
#
# From the element in the next cell select at least two properties to display.
#
# For details, see the [README](README.md).

# %% [markdown]
# ## Circuit selection and download
#
# A SONATA circuit unser `./analysis_circuit*/circuit_config.json` will be analyzed. To place the data there, we must select
# the circuit, then download it.
#
# #### Project selection
# As a first step we select one of the projects we have access to that the circuit is associated with. If the circuit of interest is part of the public OBI assets, any project can be selected.

# %%
from entitysdk import Client, LocalAssetStore
from obi_auth import get_token
from pathlib import Path

from obi_notebook import get_projects
from obi_notebook import get_entities
from obi_notebook.get_environment import get_environment

token = get_token(environment=get_environment(), auth_mode="daf")
project_context = get_projects.get_projects(token)

# %% [markdown]
# #### Circuit selection
#
# Next, we select the circuit. If you already know the unique identifier of the circuit of interest, paste it below into line 4 of the next cell.
#
# Otherwise, a widget for circuit selection will be created that allows you to simply mark the circuit of interest.

# %%
local_store_path = Path("/data")
local_store = LocalAssetStore(prefix=local_store_path)
client = Client(environment=get_environment(), project_context=project_context, token_manager=token, local_store=local_store)

# Optional: Download using unique ID
entity_ID = "<CIRCUIT-ID>"  # <<< FILL IN UNIQUE CIRCUIT ID HERE


if entity_ID != "<CIRCUIT-ID>":
    circuit_ids = [entity_ID]
else:
# Alternative: Select from a table of entities
    circuit_ids = []
    circuit_ids = get_entities.get_entities("circuit", token, circuit_ids,
                                            project_context=project_context,
                                            multi_select=False, exclude_scales=["single"],
                                            show_pages=True, page_size=12,
                                            default_scale="small", add_columns=["subject.name"])

# %% [markdown]
# ### Download circuit and select neuron population
# Next, we first have to download the selected circuit to the local system for analysis.
#
# We provide a simple helper function that takes care of this. Feel free to check the source code of the function if you want to learn more about how circuit assets are handled on the OBI platform.
#
#
# After that, we have to select a `node population` and a `node set`.
# `Node populations` are fundamental groups of neurons in a circuit in the SONATA format. For example, a circuit may contain one central `node population` about which lot of detailed information is available, and one or several surrounding populations where less detail is available and that represent extrinsic synaptic inputs into the central population.
#
# However, details depend on the circuit and the decisions that its creator made. Refer to the description of the circuit for details.
#
#
# A `node set` is a simple way to define a sub-population of a `node population`. For example, by considering only excitatory neurons, or only neurons of a specified neuron type.
#
# #### Patience...
# Depending on the size of the circuit, this step may take a while.
#
# After the download is complete, please select a `node population` and a `node set` from the selector displayed!
#
# #### Advanced
# After you stepped through the whole notebook you can come back up here and try a different selection.
# You will have to re-run all the notebook cells **below** this one, but you do not have to re-download the circuit.

# %%
from composition_helper import stage_selected_circuit_locally, nodeset_selector

circ = stage_selected_circuit_locally(client, circuit_ids[0])
nodepop, nodeset = nodeset_selector(circ)

display(nodepop)
display(nodeset)

# %% [markdown]
# ## Load neuron properties and select the ones to display
# Now we can easily load various `neuron properties`. These are simply properties that have a single value for each neuron, such as the neuron's type, its subregion (e.g., layer) or firing type.
#
# The SONATA format allows for the storage of any number and type of property. So, once again, the list of available properties and their meaning depend on the selected model. For details, you can look up the selected circuit in your OBI virtual lab and write an email to the listed contact.
#
# ### Select properties to display
# Below, we will display a selector where you can select between 2 and 8 neuron properties. In the next cell, the composition of the circuit with repsect to those properties will be displayed as a Sankey plot.
#
# ### Advanced options
# The following is entirely optional!
#
# The first line of code in the cell below loads the `neuron_properties`. After that, you can add your own code to create your own derived properties to be displayed. For example, grouping neurons into whether their `y` coordinate is above or below 1000:
# ```
# neuron_properties["below_1000"] = neuron_properties["y"] < 1000
# ```
# (Note that for this to work the `y` property must be defined in the circuit).

# %%
from composition_helper import properties_from_dataframe_selector

# Get dataframe of all properties and their values
neuron_properties = circ.nodes[nodepop.value].get(nodeset.value)
plot_title = f"Composition: {nodepop.value}/{nodeset.value}"

prop_selector = properties_from_dataframe_selector(neuron_properties)
display(prop_selector)

# %% [markdown]
# ### Display the result
#
# #### Advanced options
# You can change the order the properties are displayed in. For example, the following will invert them:
# ```
# list(prop_selector.value)[::-1]
# ```

# %%
from composition_helper import display_composition_for_selected_properties

display_composition_for_selected_properties(
    neuron_properties,
    list(prop_selector.value),
    plot_title
)
