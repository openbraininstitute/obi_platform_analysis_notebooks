# %% [markdown]
# # Stand-alone notebook for registering a new circuit
# - Checks metadata provided
# - Converts files to required formats
# - Registers circuit entity and uploads assets

# %% [markdown]
# ## Get DB client
#
# Specify environment (staging, production) and project context.

# %%
from entitysdk import Client, ProjectContext, models
from obi_auth import get_token
from uuid import UUID
from rich import print as rprint

# %%
# "My first project"
token = get_token(environment="staging")
project_context = ProjectContext.from_vlab_url("https://staging.openbraininstitute.org/app/virtual-lab/lab/82b783eb-fac6-45ec-a928-84322e3a9672/project/811aa12d-cb54-4b84-a5f7-daa24381dcdf/home")
client = Client(environment="staging", project_context=project_context, token_manager=token)

# %%
parent_id = UUID("a2518876-eb72-4a1e-8888-b5051ddaf3b2")

# %%
parent = client.get_entity(entity_id = parent_id, entity_type = models.Circuit)

# %%
rprint(parent)
# Out:
# Circuit(
#     assets=[
#         Asset(
#             id=UUID('50c60aad-93cf-4e55-a973-6178ee5df1af'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='main.png',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/main.png',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.image_png: 'image/png'>,
#             size=4570624,
#             sha256_digest='e636efeb42d077d7f2e603c4a64b6fa630c26bc0c150b32585afab83cdc3afdc',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.simulation_designer_image: 'simulation_designer_image'>
#         ),
#         Asset(
#             id=UUID('0aefcaae-1bdb-4fa4-a652-122b76f36e78'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='circuit_visualization.webp',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/circuit_visualization.webp',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.image_webp: 'image/webp'>,
#             size=947776,
#             sha256_digest='36f6b8dcc1cb811433fcf9236a7e3fe17a2aa8a28691fea7046f73388459705e',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.circuit_visualization: 'circuit_visualization'>
#         ),
#         Asset(
#             id=UUID('ecfadea9-e2d6-4e3e-b6a5-b70e3580858b'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='network_stats_b.webp',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/network_stats_b.webp',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.image_webp: 'image/webp'>,
#             size=312972,
#             sha256_digest='89e0e6031a31672a5a16064ba095b6a570d979e32d5e109f0c2830db8715199b',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.network_stats_b: 'network_stats_b'>
#         ),
#         Asset(
#             id=UUID('a2764392-15be-4ced-80d2-c1a629321b1a'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='circuit_connectivity_matrices',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/circuit_connectivity_matrices',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=True,
#             content_type=<ContentType.application_vnd_directory: 'application/vnd.directory'>,
#             size=-1,
#             sha256_digest=None,
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.circuit_connectivity_matrices: 'circuit_connectivity_matrices'>
#         ),
#         Asset(
#             id=UUID('d321965d-353c-45fa-bdff-d964c3535cd9'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='network_stats_a.webp',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/network_stats_a.webp',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.image_webp: 'image/webp'>,
#             size=68398,
#             sha256_digest='2fe997febf10ea3e52669e2ca57edc90493f1d8b5adc56b2eea5ea69eeb342bf',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.network_stats_a: 'network_stats_a'>
#         ),
#         Asset(
#             id=UUID('e6fccacd-418b-43bc-8691-82e42509731d'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='node_stats.webp',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/node_stats.webp',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.image_webp: 'image/webp'>,
#             size=41646,
#             sha256_digest='22f6f9e3826395e50d2317110c682f3a90b2149fc9a4e7052ef18dc2bef984e9',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.node_stats: 'node_stats'>
#         ),
#         Asset(
#             id=UUID('ae00c309-d806-4d78-802b-2c115b215c0a'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='sonata_circuit',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/sonata_circuit',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=True,
#             content_type=<ContentType.application_vnd_directory: 'application/vnd.directory'>,
#             size=-1,
#             sha256_digest=None,
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.sonata_circuit: 'sonata_circuit'>
#         ),
#         Asset(
#             id=UUID('39466859-f0d4-4401-b0c0-f70ad7add7a7'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             path='circuit.gz',
#             full_path='public/1f91f30e-1489-4e2a-8eb7-1217257c8e19/7a411785-6895-4839-aaa2-d9f76e09875a/assets/circ
# uit/a2518876-eb72-4a1e-8888-b5051ddaf3b2/circuit.gz',
#             storage_type=<StorageType.aws_s3_internal: 'aws_s3_internal'>,
#             is_directory=False,
#             content_type=<ContentType.application_gzip: 'application/gzip'>,
#             size=36404599,
#             sha256_digest='2505099e91ba504882fc9e20d8b4e7b51c55952c4e78d38e578df0f75d2bea55',
#             status=<AssetStatus.created: 'created'>,
#             meta={},
#             label=<AssetLabel.compressed_sonata_circuit: 'compressed_sonata_circuit'>
#         )
#     ],
#     id=UUID('a2518876-eb72-4a1e-8888-b5051ddaf3b2'),
#     creation_date=datetime.datetime(2025, 7, 1, 9, 23, 45, 8152, tzinfo=TzInfo(0)),
#     update_date=datetime.datetime(2026, 3, 31, 10, 18, 35, 655219, tzinfo=TzInfo(0)),
#     created_by=Person(
#         id=UUID('38fc8a62-5823-4129-a09e-3037d1af4834'),
#         creation_date=None,
#         update_date=None,
#         created_by=None,
#         updated_by=None,
#         type='person',
#         pref_label='Christoph Pokorny',
#         given_name='Christoph',
#         family_name='Pokorny',
#         sub_id=UUID('e41b43dc-5078-40d5-a081-12bc031f3b17')
#     ),
#     updated_by=Person(
#         id=UUID('c51a9d79-39c5-45c6-b57b-9197e5d8c0cc'),
#         creation_date=None,
#         update_date=None,
#         created_by=None,
#         updated_by=None,
#         type='person',
#         pref_label='Daniel Keller',
#         given_name='Daniel',
#         family_name='Keller',
#         sub_id=UUID('3d4e4581-1a32-4356-beb6-74099d65de96')
#     ),
#     name='rCA1-CYLINDER-REF-1PC-8PV-01',
#     description='Instance number 1 of a small microcircuit consisting of a pyramidal cell sampled in the middle of
# rCA1-CYLINDER-REF and 8 parvalbumin positive neurons that converge over it.',
#     type=<EntityType.circuit: 'circuit'>,
#     authorized_public=True,
#     authorized_project_id=UUID('7a411785-6895-4839-aaa2-d9f76e09875a'),
#     contributions=[
#         Contribution(
#             id=UUID('6c8dfe4e-8866-4195-893f-521107940227'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('a1e91aec-c02c-44ea-9a6c-32a0382855f5'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Davide Bella',
#                 given_name='Davide',
#                 family_name='Bella',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('af8fd154-12c8-494d-9303-edc858a00515'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('ef5a0bb8-e778-483f-a4d2-80bbdbcd9583'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Huanxiang Lu',
#                 given_name='Huanxiang',
#                 family_name='Lu',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('0fa2665a-a5eb-44e4-ab60-8da41e34259e'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('67d6a143-1303-4c09-a76e-40628f787c2c'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='Blue Brain Project, École polytechnique fédérale de Lausanne (EPFL), Geneva,
# Switzerland',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('7237a1a7-483d-413d-85ae-2909c7b542f4'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('545484cf-ae5c-412f-a299-9fc1abb51d18'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Marwan Abdellah',
#                 given_name='Marwan',
#                 family_name='Abdellah',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('9fba267d-67ec-48dc-b43f-94a596bc0de6'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('4067c358-4ee2-47f8-9a94-e3e8ab73738f'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Anna-Kristin Kaufmann',
#                 given_name='Anna-Kristin',
#                 family_name='Kaufmann',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('6e4d510c-ca53-4f05-ba4e-b6bbeab92372'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('fec3f6b3-2e8d-4b8a-8f54-f8ceacaab39e'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Mohameth François Sy',
#                 given_name='Mohameth François',
#                 family_name='Sy',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('35317d28-b4fe-446d-95ce-bdaf743eff50'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('2d6c797f-8f7d-4b78-aa1b-e9cd8697bbd0'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Genrich Ivaska',
#                 given_name='Genrich',
#                 family_name='Ivaska',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('38ebdac7-5122-4096-afc3-27ac391532b4'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('182c8eb9-d0e9-4504-ad68-0ac5a66bf90e'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Ying Shi',
#                 given_name='Ying',
#                 family_name='Shi',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('a6de4637-920d-45fe-b07d-e519db496472'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('f129b667-8519-43e8-9c78-c95982a2906e'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Elisabetta Giacalone',
#                 given_name='Elisabetta',
#                 family_name='Giacalone',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('0525c244-49d9-4e5d-99f1-16b38fb11a47'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('debca2b6-25d5-46d9-8455-51ad1018f3f9'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Srikanth Ramaswamy',
#                 given_name='Srikanth',
#                 family_name='Ramaswamy',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('4d295df7-cde0-4e06-a2a3-362788cd3096'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('ed49572e-d799-4461-81b7-574cff43a8ca'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='State University of New York (SUNY) Downstate Health Sciences University, Brooklyn, New
# York, USA',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('18e4a904-235d-4c15-831c-301361a486c6'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('d0e96e1f-3907-4847-b278-b8c85649e013'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Maxim Bazhenov',
#                 given_name='Maxim',
#                 family_name='Bazhenov',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('cd615e03-dfb7-468f-a38a-aef9c79a41c9'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('ad29b40a-ded8-4cf5-b454-8ceb715b5f52'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Sigrun Lange',
#                 given_name='Sigrun',
#                 family_name='Lange',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('d1aba864-00e2-406e-b02d-35e5b822f7a2'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('8df64f5f-1bc5-406b-9a4b-cef5454ed573'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='Allen Institute for Brain Science, Seattle, WA, USA',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('c2ee925e-f9b8-4da3-8d61-16b68add2715'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('8042e7d5-d595-471c-b51b-9104e361b16e'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Beatriz Herrera',
#                 given_name='Beatriz',
#                 family_name='Herrera',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('32352009-af21-479f-b93e-2bb131cadf35'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('c524d872-9c0f-4dd8-81b1-ea7a8a5252c3'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Sára Sáray',
#                 given_name='Sára',
#                 family_name='Sáray',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('8a67067c-61cc-4c4c-a53a-411e1d957406'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('121dbecc-4f38-40a4-9677-2f2792c45118'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Etay Hay',
#                 given_name='Etay',
#                 family_name='Hay',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('56c528fe-de4b-4b0d-9857-7f402493ba9f'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('43bd0656-0694-45e5-bb3c-75c8c22edb9c'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Juan Luis Riquelme',
#                 given_name='Juan Luis',
#                 family_name='Riquelme',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('be21879d-9fba-4e92-9e50-c069a827c194'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('baefbcf8-26d9-46a2-96c2-ed566816148d'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='University of California San Diego, La Jolla, California, USA',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('f32e3896-f7aa-4de3-83e6-04ac5b4d8b84'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('062c215e-d709-4000-ae67-72f44d6013aa'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Elvis Boci',
#                 given_name='Elvis',
#                 family_name='Boci',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('20b34925-f727-4c1c-98f2-04982ef0c229'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('ce5b3e7e-ba9b-498d-b5cb-c4d3f68ed036'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Carmen Alina Lupascu',
#                 given_name='Carmen Alina',
#                 family_name='Lupascu',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('1dc5ffc2-b52f-4d82-8f13-8ccb65acae66'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('a4f871a9-778d-4dba-be5e-91024cdcd842'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='Centre Hospitalier Universitaire (CHU) Sainte-Justine Research Center,  Montréal,
# Canada',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('5d4a4cad-aed6-4c8c-bbc2-41be11d53c27'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('fc977929-8a77-4ac2-a7f0-ce161cb0a312'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Alexis Arnaudon',
#                 given_name='Alexis',
#                 family_name='Arnaudon',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('0deb38c6-15de-4857-b754-a99581e0a0c1'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('e8624fab-5186-4e32-ae8d-7ee9770348a0'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Kerem Kurban',
#                 given_name='Kerem',
#                 family_name='Kurban',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('83110870-38a1-4a1a-9ae9-0fa4faba5a6e'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('fdfb0286-16dc-4265-a10a-e8a1892739f6'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Liesbeth Vanherpe',
#                 given_name='Liesbeth',
#                 family_name='Vanherpe',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('d34f1d87-80b6-4ee7-9638-bde84312f2a1'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('6c9c452e-357d-493e-a917-d363023f855c'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Anton Arkhipov',
#                 given_name='Anton',
#                 family_name='Arkhipov',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('a00cce3f-a8de-4cb3-a50a-598db5a1bf00'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('4c9ea096-cc38-4e77-904d-fe8065ed8a6f'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Pramod Kumbhar',
#                 given_name='Pramod',
#                 family_name='Kumbhar',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('de91889d-a1bc-4b55-9103-ac8567d2be29'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('61ef2a6a-aabe-4b54-90f8-66ac6718e995'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Werner Van Geit',
#                 given_name='Werner',
#                 family_name='Van Geit',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('3baaff2f-8756-446b-be00-53596066a4ce'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('5e8ec7db-b696-4e0f-9701-698599adb515'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Nadir Román Guerrero',
#                 given_name='Nadir Román',
#                 family_name='Guerrero',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('f7eed018-5f21-4f03-8f5a-bcc111f459b2'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('5480e38b-0d40-4b5e-8464-7014bcad1fe5'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Michael W. Reimann',
#                 given_name='Michael W.',
#                 family_name='Reimann',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('610b9dc3-4677-49a2-972d-826a2e480d2c'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('509a0562-aa7a-4b37-a1e6-a91b75cf0919'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='UCL School of Pharmacy, University College London (UCL), London, United Kingdom',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('9b8de0bb-6c3c-48af-a0a2-d7633a7188d5'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('eec60eb2-0f4e-418e-a84a-39c222899b24'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Daniela Gandolfi',
#                 given_name='Daniela',
#                 family_name='Gandolfi',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('ae29c4be-2832-4769-a282-ca2501f5f629'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('24fbc413-d5e1-4cb0-b97a-e62ad2b57d6f'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Judit Planas',
#                 given_name='Judit',
#                 family_name='Planas',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('9229f19d-f1a4-4e8d-94d4-72556e363911'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('fb28664a-01c8-4f24-a7f7-4223eab11b6e'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='School of Life Sciences, University of Westminster, London, United Kingdom',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('26751218-5a9e-4397-8db9-7ee421acc7da'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('8da7149c-4a27-4ebf-9e26-cff1fadf74da'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Tamás F. Freund',
#                 given_name='Tamás F.',
#                 family_name='Freund',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('0a51fd81-9766-4b75-821d-c32a4432bf09'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('23b61c66-7b41-49d9-908a-ffee3dd4aeda'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Fabien Petitjean',
#                 given_name='Fabien',
#                 family_name='Petitjean',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
# ...
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Felix Schürmann',
#                 given_name='Felix',
#                 family_name='Schürmann',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('2cba40ea-80c3-40b2-b1b7-454f25bf7bea'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('2b68abef-41db-4351-83a0-614fb7222606'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Julian Budd',
#                 given_name='Julian',
#                 family_name='Budd',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('3c608fc6-54be-492a-9ffb-c45462164510'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('93af6747-a89f-4e61-a76e-8f4d9d9dc69d'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Addolorata Marasco',
#                 given_name='Addolorata',
#                 family_name='Marasco',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('4802fce9-f558-4eae-ae50-2617e363cb66'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('acc31673-1338-44c8-a7b0-93234de572ad'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='Department of Engineering "Enzo Ferrari", University of Modena and Reggio Emilia,
# Modena, Italy',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('b9e92671-08b1-4ec6-8341-bfd546a8424f'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('0c3fd390-c0d3-47af-8b52-bf71dc70e0e3'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Thomas Delemontex',
#                 given_name='Thomas',
#                 family_name='Delemontex',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('c76b7faa-965a-4f1d-8c6c-8399386f5356'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('ba51289f-95fd-448c-9595-661deb2812ef'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Audrey Mercer',
#                 given_name='Audrey',
#                 family_name='Mercer',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('4f9a8512-21bd-412e-8641-81aa36b80d2c'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('934b2c78-17dc-4eed-9362-c429aaec0030'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='HUN-REN Institute of Experimental Medicine (KOKI), Budapest, Hungary',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('05c6751e-fc72-48b4-ae46-48c26ffd6836'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('a385509d-240b-43fd-8702-0d2c345cb1a7'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='University of Toronto, Toronto, Ontario, Canada',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('bf65e5c4-afb6-4e01-90a8-bde77448d0b0'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('b559e8ca-3b50-4af2-a3fd-f8f24bdfb98f'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Alberto Antonietti',
#                 given_name='Alberto',
#                 family_name='Antonietti',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('4f087beb-ce2d-4775-882e-1eb1d6c27dae'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('9d7250b3-ac91-4e4f-b1d4-832e80ea74aa'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='James Gonzalo King',
#                 given_name='James Gonzalo',
#                 family_name='King',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('1df0c55e-ea5f-4007-9d1d-555630977ffa'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Person(
#                 id=UUID('46ab456c-3342-40bd-81ad-79eaf78a28cb'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='person',
#                 pref_label='Alex M. Thomson',
#                 given_name='Alex M.',
#                 family_name='Thomson',
#                 sub_id=None
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         ),
#         Contribution(
#             id=UUID('43c64b10-dc94-4922-93a3-d015a8b82289'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             agent=Organization(
#                 id=UUID('f87b73b2-78d7-4c12-a001-64fcc0bf4864'),
#                 creation_date=None,
#                 update_date=None,
#                 created_by=None,
#                 updated_by=None,
#                 type='organization',
#                 pref_label='Open Brain Institute, Lausanne, Switzerland',
#                 alternative_name=''
#             ),
#             role=Role(
#                 id=UUID('a48b7ff5-1284-4e47-9680-6cfb1f5c88de'),
#                 creation_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 update_date=datetime.datetime(2025, 6, 27, 11, 10, 53, 209515, tzinfo=TzInfo(0)),
#                 created_by=None,
#                 updated_by=None,
#                 name='unspecified',
#                 role_id='unspecified'
#             ),
#             entity=None
#         )
#     ],
#     legacy_id=None,
#     experiment_date=datetime.datetime(2024, 11, 1, 0, 0, tzinfo=TzInfo(0)),
#     contact_email='romani.armando@gmail.com',
#     subject=Subject(
#         assets=[],
#         id=UUID('445edb11-40ee-431f-b9d2-e9e96deab8f9'),
#         creation_date=None,
#         update_date=None,
#         created_by=None,
#         updated_by=None,
#         name='Average rat',
#         description='Abstract representation of a rat model built from average statistical metrics across
# individual rats',
#         type=None,
#         authorized_public=False,
#         authorized_project_id=None,
#         contributions=None,
#         legacy_id=None,
#         sex=<Sex.unknown: 'unknown'>,
#         weight=None,
#         age_value=None,
#         age_min=None,
#         age_max=None,
#         age_period=None,
#         species=Species(
#             id=UUID('3b1c2a25-b4fb-468d-98d2-d2d431ac8b4a'),
#             creation_date=None,
#             update_date=None,
#             created_by=None,
#             updated_by=None,
#             name='Rattus norvegicus',
#             taxonomy_id='NCBITaxon:10116'
#         ),
#         strain=None
#     ),
#     brain_region=BrainRegion(
#         id=UUID('f11a8cad-9792-4aa3-8f7a-e4ed92433d61'),
#         creation_date=None,
#         update_date=None,
#         created_by=None,
#         updated_by=None,
#         name='Cornu ammonis 1',
#         annotation_value=98,
#         acronym='CA1',
#         parent_structure_id=UUID('2047bfd9-1193-4f27-be9b-6e300b4ba1bc'),
#         hierarchy_id=UUID('db5b35e6-585b-4418-a668-7923ae6e8599'),
#         color_hex_triplet='d9680d',
#         species=None,
#         strain=None
#     ),
#     license=License(
#         id=UUID('ad8686db-3cdd-4e3f-bcbd-812380a9eba7'),
#         creation_date=datetime.datetime(2024, 1, 10, 15, 58, 46, 7611, tzinfo=TzInfo(0)),
#         update_date=datetime.datetime(2025, 10, 6, 8, 30, 44, 319417, tzinfo=TzInfo(0)),
#         created_by=None,
#         updated_by=None,
#         name='https://creativecommons.org/licenses/by/4.0/',
#         description='Creative Commons Corporation ("Creative Commons") is not a law firm and does not provide legal
# services or legal advice. Distribution of Creative Commons public licenses does not create a lawyer-client or other
# relationship. Creative Commons makes its licenses and related information available on an "as-is" basis. Creative
# Commons gives no warranties regarding its licenses, any material licensed under their terms and conditions, or any
# related information. Creative Commons disclaims all liability for damages resulting from their use to the fullest
# extent possible.',
#         label='CC BY 4.0'
#     ),
#     published_in='Romani et al.',
#     notice_text=None,
#     has_morphologies=True,
#     has_point_neurons=False,
#     has_electrical_cell_models=True,
#     has_spines=False,
#     number_neurons=9,
#     number_synapses=291,
#     number_connections=38,
#     scale=<CircuitScale.small: 'small'>,
#     build_category=<CircuitBuildCategory.computational_model: 'computational_model'>,
#     root_circuit_id=UUID('0816bb0c-48d5-42bb-a9a7-44165ddb2496'),
#     atlas_id=None
# )

# %% [markdown]
# ## Circuit information **→ To be filled in**
#
# ### General metadata
#
# To be provided as a dict with key/value pairs. Optional entries can be set to None.
#
# **Linked entities must exist in entitycore. Otherwise, they must first be registered:**
# - Species
# - Subject
# - Brain region
# - License

# %%
circuit_metadata = {
    # Name of the circuit
    "name": parent.name + "-AD",

    # Description of the circuit
    "description": f"Modification of the original {parent.name} with reduction of 50% of g_bar for Ih current in PC",
    
    # Scale of the circuit (single, pair, small, microcircuit, region, system, whole_brain)
    "scale": parent.scale,

    # Optional: Name of the root circuit (= top parent in the extraction/derivation hierarchy), if any
    "root": None,

    # Optional: Name of the parent circuit (=direct parent the circuit was extracted or derived from)
    "parent": None,

    # Optional: Type of circuit derivation (circuit_extraction, circuit_rewiring), if parent provided
    "derivation_type": None,

    # Species name [Must exist in entitycore; otherwise, must first be registered]
    "species": parent.subject.species.name,

    # Subject name [Must exist in entitycore; otherwise, must first be registered]
    "subject": parent.subject.name,

    # Brain region name [Must exist in entitycore; otherwise, must first be registered]
    "brain_region": parent.brain_region.name,

    # Optional: License name [Must exist in entitycore; otherwise, must first be registered]
    "license": parent.license.label,

    # Optional: Short, human readable publication string
    "published_in": parent.published_in,

    # Optional: Contact e-mail address
    "contact": parent.contact_email,

    # Optional: Experiment date (=date when the circuit has been build or published)
    # Note: Two date formats supported: "November, 2024" (treated as 01.11.2024) and "27.03.2024"
    "experiment_date": "November, 2024",

    # Circuit build category (computational_model, em_reconstruction)
    "build_category": "computational_model",

    # Properties of the circuit
    "has_morphologies": True,
    "has_point_neurons": False,
    "has_electrical_cell_models": True,
    "has_spines": False,

    "number_neurons": parent.number_neurons,  # Number of intrinsic neurons
    "number_synapses": parent.number_synapses,  # Number of intrinsic synapses; for synaptomes only: incl. extrinsic synapses
    "number_connections": parent.number_connections,  # [Optional] Number of intrinsic connections; for synaptomes only: incl. extrinsic connections
    }

# %% [markdown]
# ### Optional: Publications
#
# To be provided as a dict:
# - Key = DOI **[Must exist in entitycore; otherwise, must first be registered]**
# - Value = Dict with
#   - "type" (entity_source, component_source, application)

# %%
circuit_publications = {
    }

# %% [markdown]
# ### Optional: Contributors
#
# To be provided as a dict:
# - Key = Agent name **[Must exist in entitycore; otherwise, must first be registered]**
# - Value = Dict with
#   - "type" (person, organization, consortium)
#   - "role" (unspecified, ...)

# %%
circuit_contributions = {
    "Armando Romani": {"type": "person", "role": "unspecified"}
 }

# %% [markdown]
# ### Circuit file paths
#
# Path to the SONATA circuit folder containing the `circuit_config.json`, and optional paths to the figures, compressed circuit, and connectivity matrix (can be registered later, if not provided).
#
# All paths may be paths on the **local file system** or on **AWS S3 Open Data**.

# %%
# Mandatory: SONATA circuit folder with circuit_config.json
circuit_path = "./rCA1-CYLINDER-REF-1PC-8PV-01-AD/"

# Optional: Main figure (.webp) to be displayed on the platform
main_figure_path = None

# Optional: Sim designer figure (.png) to be displayed on the platform
sim_designer_figure_path = None

# Optional: Compressed SONATA circuit in gzip (.gz) format
compressed_circuit_path = None

# Optional: Connectivity matrix folder containing a matrix_config.json
matrix_path = None

# Optional: Basic node/edge statistics figures (.webp)
node_stats_figure_path = None  # Basic node statistics
network_stats_a_figure_path = None  # Global network statistics (large circuits) or small network statistict (small circuits)
network_stats_b_figure_path = None  # Pathway network statistics (large circuit) or 2D visualization (small circuits)

# %% [markdown]
# ### Optional: Convert individual files from .png -> .webp, if needed

# %%
# from register_circuit_helpers import convert_png_to_webp

# %%
# png_path_in = "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Figures/nbS1/main.png"
# webp_path_out = "/Users/pokorny/OneDrive - Open Brain Institute/Circuits hardcoded/Figures/nbS1/circuit_visualization.webp"
# convert_png_to_webp(png_path_in, webp_path_out, overwrite=False)

# %% [markdown]
# ## Check provided metadata and dependencies

# %%
from register_circuit_helpers import check_if_circuit_exists, check_counts, get_contributions, get_brain_region, get_exp_date, get_license, get_parent_circuit, get_publications, get_root_circuit, get_subject

# %% [markdown]
# ### Check if circuit is registered in entitycore already
#
# The circuit must not exist in entitycore yet!

# %%
check_if_circuit_exists(client, circuit_metadata)
# Out:
# Circuit 'rCA1-CYLINDER-REF-1PC-8PV-01-AD' not yet registered.

# %% [markdown]
# ### Check and retrieve dependencies
#
# All dependencies must already exist in entitycore!

# %%
# Check/get subject
subject = get_subject(client, circuit_metadata)

# Check/get brain region
# brain_region = get_brain_region(client, circuit_metadata)
brain_region_id=UUID('f11a8cad-9792-4aa3-8f7a-e4ed92433d61')
brain_region = client.get_entity(entity_id=brain_region_id, entity_type=models.BrainRegion)

# Check/get license
license = get_license(client, circuit_metadata)

# Check/get root circuit
root = get_root_circuit(client, circuit_metadata)

# Check/get parent circuit [Note: Parent = Derivation of type <derivation_type>]
parent = get_parent_circuit(client, circuit_metadata)

# Check neuron/synapse/connection counts
check_counts(circuit_metadata)

# Determine experimental data
# Note: Two date formats supported: "November, 2024" (treated as 01.11.2024) and "27.03.2024"
exp_date = get_exp_date(circuit_metadata)

# Check/get contributing agents
contribution_dict = get_contributions(client, circuit_contributions, verbose=False)

# Check/get publications
publication_dict = get_publications(client, circuit_publications, verbose=False)
# Out:
# Subject 'Average rat' (ID 445edb11-40ee-431f-b9d2-e9e96deab8f9)
# License 'CC BY 4.0' https://creativecommons.org/licenses/by/4.0/ (ID ad8686db-3cdd-4e3f-bcbd-812380a9eba7)
# Root circuit: None
# Parent circuit: None
# #Neurons: 9, #Synapses: 291, #Connections: 38, Scale: small
# Experiment date: 2024-11-01 00:00:00
# WARNING: Person 'Armando Romani' found multiple times - using first instance!
# Contributors: {'Person': 1}
# Publications: {}

# %% [markdown]
# ## Register circuit entity, assets, and links
#
# - Use `check_only` for a dry run without actual registration first!
# - Use `make_public` to register as a public entity

# %%
check_only = False  # If True, only check, no actual registration
make_public = False  # Register as public entity

# %%
from register_circuit_helpers import register_circuit_entity, register_asset, register_contributions, register_derivation, register_publication_links

# %% [markdown]
# ### Register circuit entity

# %%
# Create & register circuit entity
registered_circuit = register_circuit_entity(client, circuit_metadata, subject, brain_region, license, root, exp_date, make_public=make_public, check_only=check_only)
# Out:
# Circuit entity 'rCA1-CYLINDER-REF-1PC-8PV-01-AD': ID 61c3e983-70f9-4aef-85fc-f0a193a7134b

# %% [markdown]
# ### Register assets
# - SONATA circuit folder
# - Optional: Overview/sim designer image
# - Optional: Compressed SONATA circuit
# - Optional: Connectivity matrix folder
# - Optional: Basic connectivity figures

# %%
# Register circuit folder asset
circuit_folder_asset = register_asset(client, file_path=circuit_path, asset_label="sonata_circuit", registered_circuit=registered_circuit, check_only=check_only)

# Register compressed circuit asset
gz_asset = register_asset(client, file_path=compressed_circuit_path, asset_label="compressed_sonata_circuit", registered_circuit=registered_circuit, check_only=check_only)

# Connectivity matrix folder asset
matrix_folder_asset = register_asset(client, file_path=matrix_path, asset_label="circuit_connectivity_matrices", registered_circuit=registered_circuit, check_only=check_only)

# Main circuit figure for detailed explore page
main_fig_asset = register_asset(client, file_path=main_figure_path, asset_label="circuit_visualization", registered_circuit=registered_circuit, check_only=check_only)

# Circuit figure for simulation designer
sim_fig_asset = register_asset(client, file_path=sim_designer_figure_path, asset_label="simulation_designer_image", registered_circuit=registered_circuit, check_only=check_only)

# Basic connectivity plots
node_stats_fig_asset = register_asset(client, file_path=node_stats_figure_path, asset_label="node_stats", registered_circuit=registered_circuit, check_only=check_only)
network_stats_a_fig_asset = register_asset(client, file_path=network_stats_a_figure_path, asset_label="network_stats_a", registered_circuit=registered_circuit, check_only=check_only)
network_stats_b_fig_asset = register_asset(client, file_path=network_stats_b_figure_path, asset_label="network_stats_b", registered_circuit=registered_circuit, check_only=check_only)
# Out:
# WARNING: 3 '.DS_Store' file(s) found in `./rCA1-CYLINDER-REF-1PC-8PV-01-AD` - IGNORING
# assetID (sonata_circuit): ea6bf763-4288-4c8a-a44e-e3202d9174f1
# INFO: No path for 'compressed_sonata_circuit' asset provided - SKIPPING
# INFO: No path for 'circuit_connectivity_matrices' asset provided - SKIPPING
# INFO: No path for 'circuit_visualization' asset provided - SKIPPING
# INFO: No path for 'simulation_designer_image' asset provided - SKIPPING
# INFO: No path for 'node_stats' asset provided - SKIPPING
# INFO: No path for 'network_stats_a' asset provided - SKIPPING
# INFO: No path for 'network_stats_b' asset provided - SKIPPING

# %% [markdown]
# ### Register entity links
# - Derivation links (if any)
# - Contribution links (if any)
# - Publication links (if any)

# %%
# Derivation links
derivation = register_derivation(client, from_entity=parent, derivation_type=circuit_metadata.get("derivation_type"), registered_circuit=registered_circuit, check_only=check_only)

# Contribution links
contributions = register_contributions(client, contribution_dict=contribution_dict, registered_circuit=registered_circuit, check_only=check_only)
    
# Publication links
publ_links = register_publication_links(client, publication_dict=publication_dict, registered_circuit=registered_circuit, check_only=check_only)
# Out:
# INFO: No derivation parent provided - SKIPPING
# Contributions: 1 registered
# Publication links: 0 registered
